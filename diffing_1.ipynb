# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
a=10
b=11
print(a+b)
# Out:
# 21

# %%
x=25
y=13
print(x+y)
# Out:
# 38

# %%
data=pd.DataFrame({
    "X" : [1,2,3,4,5],
    "Y" : [1,2,3,4,5]
})
plt.plot(data['X'],data['Y'],label="Equation of line: y=x")
plt.grid()
plt.legend()
plt.show()
