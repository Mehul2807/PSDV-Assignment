# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %%
x=10
y=11
print(x+y)
# Out:
# 21

# %%
data=pd.DataFrame({
    "x": [1,9],
    "y": [6,2]
})
plt.plot(data["x"],data["y"])
plt.grid()
plt.xlim(1,9)
plt.ylim(2,6)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import nbdime
# ----> 2 di = nbdime.diff_notebooks(notebook_1.ipynb,notebook_2.ipynb)
#       3 assert not di
#
# NameError: name 'notebook_1' is not defined
