# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %%
x=10
y=11
print(y-x)
# Out:
# 1

# %%
data=pd.DataFrame({
    "x": [1,9],
    "y": [2,3]
})
plt.plot(data["x"],data["y"])
plt.grid()
plt.xlim(1,9)
plt.ylim(2,6)
plt.show()

# %%
print("Hello World")
